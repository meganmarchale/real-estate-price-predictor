# %%
import os
import sys
import json
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.feature_selection import SelectFromModel

# Add the project root to the Python path
project_root = os.path.abspath("../..")
sys.path.append(project_root)

# Import project constants
from utils.constants import ML_READY_DATA_FILE, MODELS_DIR

# Step 1: Load the ML-ready dataset
df = pd.read_csv(ML_READY_DATA_FILE)
X = df.drop(columns=["id", "url", "price"], errors="ignore")
y = df["price"]

# Step 2: Fit a RandomForest to select the top 30 most important features
rf = RandomForestRegressor(random_state=42)
rf.fit(X, y)

selector = SelectFromModel(rf, threshold=-float("inf"), max_features=30, prefit=True)
top30_features = list(X.columns[selector.get_support()])

# Step 3: Save the full and top30 feature lists as JSON
features_dir = os.path.join(MODELS_DIR, "features")
os.makedirs(features_dir, exist_ok=True)

with open(os.path.join(features_dir, "all_features.json"), "w") as f:
    json.dump(list(X.columns), f, indent=2)

with open(os.path.join(features_dir, "top30_features.json"), "w") as f:
    json.dump(top30_features, f, indent=2)

print("Feature JSON files saved successfully.")
# Out:
# Feature JSON files saved successfully.

# %%
import sys, os
import json
from glob import glob
import pandas as pd
from joblib import load
from datetime import datetime

# Add the project root to the Python path
project_root = os.path.abspath("../..")
sys.path.append(project_root)

# Import project constants
from utils.constants import (
    ML_READY_DATA_FILE,
    MODELS_DIR,
    PREDICTIONS_DIR
)

# Step 1: Load the machine learning-ready dataset
if not os.path.exists(ML_READY_DATA_FILE):
    raise FileNotFoundError(f"ML-ready dataset not found at: {ML_READY_DATA_FILE}")

print(f"Using ML-ready dataset: {os.path.basename(ML_READY_DATA_FILE)}")
df = pd.read_csv(ML_READY_DATA_FILE)

# Step 2: Randomly select 10 properties for inference
df_sample = df.sample(n=10, random_state=42).reset_index(drop=True)
print("10 random properties selected for prediction.")

# Remove non-feature columns
base_features = df_sample.drop(columns=["id", "url"], errors="ignore")

# Step 3: Load feature lists for top30 and all features
features_dir = os.path.join(MODELS_DIR, "features")
top30_path = os.path.join(features_dir, "top30_features.json")
all_path = os.path.join(features_dir, "all_features.json")

with open(top30_path, "r") as f:
    top30_features = json.load(f)
with open(all_path, "r") as f:
    all_features = json.load(f)

# Step 4: Load all .pkl models and perform prediction
models_pkl_dir = os.path.join(MODELS_DIR, "pkl")
pkl_files = glob(os.path.join(models_pkl_dir, "*.pkl"))

if not pkl_files:
    raise ValueError(f"No .pkl models found in: {models_pkl_dir}")

predictions = df_sample.copy()

for pkl_path in pkl_files:
    model_name = os.path.basename(pkl_path).replace(".pkl", "")
    try:
        model = load(pkl_path)

        # Choose the correct feature set based on model name
        if "top30" in model_name.lower():
            features = top30_features
        else:
            features = all_features

        # Prepare input data
        X_input = base_features[features]

        # Make predictions
        preds = model.predict(X_input)
        predictions[model_name] = preds
        print(f"Prediction completed for model: {model_name}")

    except Exception as e:
        print(f"Failed prediction for model '{model_name}': {e}")

# Step 5: Save the predictions to output directory
os.makedirs(PREDICTIONS_DIR, exist_ok=True)
timestamp = datetime.now().strftime("%Y%m%d_%H%M")
output_file = f"inference_predictions_{timestamp}.csv"
output_path = os.path.join(PREDICTIONS_DIR, output_file)

predictions.to_csv(output_path, index=False)
print(f"Inference predictions saved to: {output_path}")
# Out:
# Using ML-ready dataset: immoweb_real_estate_ml_ready.csv
# 10 random properties selected for prediction.
# Prediction completed for model: catboost_optuna_all_20250629_0814_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1033_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1102_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1111_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1234_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1257_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1303_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1311_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1320_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1329_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1408_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1423_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1454_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1524_TEST
# Prediction completed for model: catboost_optuna_all_20250629_1553_TEST
# Failed prediction for model 'catboost_optuna_top30_20250629_0814_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1033_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1102_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1111_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1234_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1257_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1303_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1311_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1320_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1329_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1408_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1423_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1454_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1524_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'catboost_optuna_top30_20250629_1553_TEST': C:/Go_Agent/pipelines/BuildMaster/catboost.git/catboost/libs/data/model_dataset_compatibility.cpp:81: At position 0 should be feature with name habitableSurface (found bedroomCount).
# Failed prediction for model 'xgboost_optuna_all_20250629_0812_TEST': feature_names mismatch: ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'type_HOUSE', 'subtype_APARTMENT', 'subtype_APARTMENT_BLOCK', 'subtype_DUPLEX', 'subtype_GROUND_FLOOR', 'subtype_HOUSE', 'subtype_MIXED_USE_BUILDING', 'subtype_PENTHOUSE', 'subtype_TOWN_HOUSE', 'subtype_VILLA', 'province_Antwerp', 'province_Brussels', 'province_East Flanders', 'province_Flemish Brabant', 'province_Hainaut', 'province_Limburg', 'province_Liège', 'province_Luxembourg', 'province_Namur', 'province_Walloon Brabant', 'province_West Flanders', 'locality_Anderlecht', 'locality_Antwerpen', 'locality_Bruxelles', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke-Heist', 'locality_Liège', 'locality_Uccle', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_JUST_RENOVATED', 'buildingCondition_TO_BE_DONE_UP', 'buildingCondition_TO_RENOVATE', 'buildingCondition_nan', 'floodZoneType_NON_FLOOD_ZONE', 'floodZoneType_POSSIBLE_FLOOD_ZONE', 'floodZoneType_RECOGNIZED_FLOOD_ZONE', 'floodZoneType_nan', 'heatingType_ELECTRIC', 'heatingType_FUELOIL', 'heatingType_GAS', 'heatingType_PELLET', 'heatingType_nan', 'kitchenType_HYPER_EQUIPPED', 'kitchenType_INSTALLED', 'kitchenType_NOT_INSTALLED', 'kitchenType_SEMI_EQUIPPED', 'kitchenType_USA_HYPER_EQUIPPED', 'kitchenType_USA_INSTALLED', 'kitchenType_nan', 'epcScore_A', 'epcScore_A+', 'epcScore_B', 'epcScore_C', 'epcScore_D', 'epcScore_E', 'epcScore_F', 'epcScore_G', 'hasLivingRoom', 'hasTerrace'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'is_big_property', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'type_HOUSE', 'subtype_APARTMENT', 'subtype_APARTMENT_BLOCK', 'subtype_BUNGALOW', 'subtype_CHALET', 'subtype_COUNTRY_COTTAGE', 'subtype_DUPLEX', 'subtype_EXCEPTIONAL_PROPERTY', 'subtype_FARMHOUSE', 'subtype_FLAT_STUDIO', 'subtype_GROUND_FLOOR', 'subtype_HOUSE', 'subtype_KOT', 'subtype_LOFT', 'subtype_MANOR_HOUSE', 'subtype_MANSION', 'subtype_MIXED_USE_BUILDING', 'subtype_OTHER_PROPERTY', 'subtype_PENTHOUSE', 'subtype_SERVICE_FLAT', 'subtype_TOWN_HOUSE', 'subtype_TRIPLEX', 'subtype_VILLA', 'province_Antwerp', 'province_Brussels', 'province_East Flanders', 'province_Flemish Brabant', 'province_Hainaut', 'province_Limburg', 'province_Liège', 'province_Luxembourg', 'province_Namur', 'province_Walloon Brabant', 'province_West Flanders', "locality_'S-GRAVENWEZEL", "locality_'s-Gravenwezel", 'locality_AALBEKE', 'locality_AALST', 'locality_AARSCHOT', 'locality_AARTSELAAR', 'locality_ACHTERBROEK', 'locality_ACHÊNE', 'locality_ADINKERKE', 'locality_AISEAU', 'locality_ALKEN', 'locality_ALLEUR', 'locality_ALSEMBERG', 'locality_AMAY', 'locality_AMOUGIES', 'locality_AMPSIN', 'locality_ANDENNE', 'locality_ANDERLECHT', 'locality_ANDERLUES', 'locality_ANGLEUR', 'locality_ANNEVOIE-ROUILLON', 'locality_ANS', 'locality_ANSEREMME', 'locality_ANTOING', 'locality_ANTWERPEN', 'locality_ANZEGEM', 'locality_APPELS', 'locality_ARCHENNES', 'locality_ARENDONK', 'locality_ARGENTEAU', 'locality_ARLON', 'locality_ARQUENNES', 'locality_ASPER', 'locality_ASSE', 'locality_ASSENEDE', 'locality_ASSESSE', 'locality_ASTENE', 'locality_ATH', 'locality_ATHUS', 'locality_ATTERT', 'locality_AUBANGE', 'locality_AUDERGHEM', 'locality_AULNOIS', 'locality_AUVELAIS', 'locality_AVELGEM', 'locality_AVERBODE', 'locality_AVERNAS-LE-BAUDUIN', 'locality_AVIN', 'locality_AWANS', 'locality_AWIRS', 'locality_AYWAILLE', 'locality_Aalbeke', 'locality_Aalst', 'locality_Aalst (9300)', 'locality_Aalst - Baardegem', 'locality_Aalst Baardegem', 'locality_Aalst Erembodegem', 'locality_Aalst Gijzegem', 'locality_Aalst Moorsel', 'locality_Aalst Nieuwerkerken', 'locality_Aalter', 'locality_Aarlen', 'locality_Aarschot', 'locality_Aarschot Langdorp', 'lo ...
# training data did not have the following fields: locality_Virton Saint-Mard, locality_NEERPELT, locality_Willebroek Heindonk, locality_Charleroi Mont-sur-Marchienne, locality_Loverval, locality_Lambusart, locality_Oudergem, locality_CORROY-LE-GRAND, locality_Villers-le-Bouillet, locality_Jandrain-jandrenouille, locality_ELVERDINGE, locality_ANDERLECHT, locality_PELLENBERG, locality_Saint-Georgessur-Meuse, locality_VILLERS-LA-LOUE, locality_Heist-aan-Zee, locality_Hasselt Kermt, locality_Antwerpen Kiel, locality_Lochristi, locality_VELTEM-BEISEM, locality_DWORP, locality_Bonheiden Rijmenam, locality_Berchem, locality_Ichtegem, locality_WALEM, locality_WICHELEN, locality_FONTAINE-L'EVEQUE, locality_La Louvière Saint-Vaast, locality_Strombeek-Bever, locality_Waregem Beveren-Leie, locality_PONT-DE-LOUP, epcScore_A++, locality_Thimister, locality_LOKEREN, locality_Pont-de-loup, locality_Lauw, locality_HEURE, locality_Modave Outrelouxhe, locality_VITRIVAL, locality_Wervik, locality_ANDENNE, locality_Ninove, locality_Ooigem, locality_HOEGAARDEN, locality_Court-saint-Étienne, locality_LAMBUSART, locality_Vaux-sous-Chèvremont, locality_Marcinelle, locality_Bornem Hingene, locality_ZELLIK, locality_Diksmuide, locality_Evregnies, locality_Kortrijk-Dutsel, locality_BAZEL, locality_Leeuw-Saint-Pierre, locality_Zonhoven, locality_Molenbeersel, locality_Saint-nicolas, locality_Tongeren, locality_BACHTE-MARIA-LEERNE, locality_Feneur, locality_Hoogstraten, locality_PUURS-SINT-AMANDS, locality_Awans Othée, locality_WAREGEM, locality_Jodoigne, locality_ATHUS, locality_Louveigné, locality_Hulste, locality_Lommel, locality_COURCELLES, locality_Poppel, locality_GULLEGEM, locality_LATHUY, locality_SINT-PIETERS-LEEUW, locality_Willebroek Tisselt, locality_FIZE-FONTAINE, locality_Fayembois, locality_Francorchamps, locality_Chaudfontaine Beaufays, locality_QUIÉVRAIN, locality_Oppuurs, locality_Grimbergen Strombeek-Bever, locality_Sint-Denijs-Westrem, locality_Pâturages, locality_Gent Gentbrugge, locality_Ranst, locality_Wielsbeke, locality_LE ROEULX, locality_ARENDONK, locality_Zwevegem, locality_Mettet Ermetonsur-Biert, locality_Schendelbeke, locality_Gedinne Louette-Saint-Denis, locality_Messancy Wolkrange, locality_Leuven Wilsele, locality_Herseaux, locality_ALLEUR, locality_Sint-Lambrechts-Woluwe, locality_Herve Battice, locality_Heist-op-den-Berg Wiekevorst, locality_Hoogstraten Wortel, locality_HERENT, locality_Onhaye Sommière, locality_TIENEN, locality_Zwijnaarde, locality_Perwez Malèves-Ste-Marie-Wastines, locality_WAYAUX, locality_BRAKEL, locality_Veurne, locality_Florenville Chassepierre, locality_Vance, locality_TOHOGNE, locality_Hakendover, locality_VILLERS-SAINTE-GERTRUDE, locality_Mont (Yvoir), locality_Antoing, locality_Nieuwenhove, locality_Merksplas, locality_Celles Velaines, locality_Hannut Poucet, locality_Remicourt, locality_LAEKEN (BRU.), locality_TARCIENNE, locality_HABAY, locality_BOOISCHOT, locality_Godinne, locality_Orp-Jauche, locality_Grâce-hollogne, locality_Ronsele, locality_Jupille-sur-Meuse, locality_Blankenberghe, locality_AUVELAIS, locality_Lierde, locality_PETIT-ENGHIEN, locality_Melle, locality_Overijse, locality_SINAAI-WAAS, locality_Bambrugge, locality_SCHAERBEEK, locality_Cortenbergh, locality_Oplinter, locality_Faimes, locality_CRISNÉE, locality_HERVE, locality_BAASRODE, locality_Verlaine, locality_Fléron Romsée, locality_Tertre, locality_Thy-le-château, locality_Wechelderzande, locality_Herzele, locality_HEIKRUIS, locality_Manderfeld, locality_Temse, locality_Londerzeel-Sint-Jozef, locality_Vlijtingen, locality_LETTELINGEN, locality_NOTHOMB, locality_Genappe, locality_Forest, locality_KRUIBEKE, locality_Geetbets, locality_Ohain, locality_Mortsel, locality_CHIMAY, locality_La Roche-en-Ardenne, Halleux, locality_Barchon, locality_OPHASSELT, subtype_OTHER_PROPERTY, locality_BEHO, locality_Jemeppe-Sur-Meuse, locality_MELSBROEK, locality_LOMBISE, locality_WASMES, locality_WANFERCÉE-BAULET, locality_TOURNAI, locality_H ...
# Failed prediction for model 'xgboost_optuna_all_20250629_0951_TEST': feature_names mismatch: ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'type_HOUSE', 'subtype_APARTMENT', 'subtype_APARTMENT_BLOCK', 'subtype_DUPLEX', 'subtype_GROUND_FLOOR', 'subtype_HOUSE', 'subtype_MIXED_USE_BUILDING', 'subtype_PENTHOUSE', 'subtype_TOWN_HOUSE', 'subtype_VILLA', 'province_Antwerp', 'province_Brussels', 'province_East Flanders', 'province_Flemish Brabant', 'province_Hainaut', 'province_Limburg', 'province_Liège', 'province_Luxembourg', 'province_Namur', 'province_Walloon Brabant', 'province_West Flanders', 'locality_Anderlecht', 'locality_Antwerpen', 'locality_Bruxelles', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke-Heist', 'locality_Liège', 'locality_Uccle', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_JUST_RENOVATED', 'buildingCondition_TO_BE_DONE_UP', 'buildingCondition_TO_RENOVATE', 'buildingCondition_nan', 'floodZoneType_NON_FLOOD_ZONE', 'floodZoneType_POSSIBLE_FLOOD_ZONE', 'floodZoneType_RECOGNIZED_FLOOD_ZONE', 'floodZoneType_nan', 'heatingType_ELECTRIC', 'heatingType_FUELOIL', 'heatingType_GAS', 'heatingType_PELLET', 'heatingType_nan', 'kitchenType_HYPER_EQUIPPED', 'kitchenType_INSTALLED', 'kitchenType_NOT_INSTALLED', 'kitchenType_SEMI_EQUIPPED', 'kitchenType_USA_HYPER_EQUIPPED', 'kitchenType_USA_INSTALLED', 'kitchenType_nan', 'epcScore_A', 'epcScore_A+', 'epcScore_B', 'epcScore_C', 'epcScore_D', 'epcScore_E', 'epcScore_F', 'epcScore_G', 'hasLivingRoom', 'hasTerrace'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'is_big_property', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'type_HOUSE', 'subtype_APARTMENT', 'subtype_APARTMENT_BLOCK', 'subtype_BUNGALOW', 'subtype_CHALET', 'subtype_COUNTRY_COTTAGE', 'subtype_DUPLEX', 'subtype_EXCEPTIONAL_PROPERTY', 'subtype_FARMHOUSE', 'subtype_FLAT_STUDIO', 'subtype_GROUND_FLOOR', 'subtype_HOUSE', 'subtype_KOT', 'subtype_LOFT', 'subtype_MANOR_HOUSE', 'subtype_MANSION', 'subtype_MIXED_USE_BUILDING', 'subtype_OTHER_PROPERTY', 'subtype_PENTHOUSE', 'subtype_SERVICE_FLAT', 'subtype_TOWN_HOUSE', 'subtype_TRIPLEX', 'subtype_VILLA', 'province_Antwerp', 'province_Brussels', 'province_East Flanders', 'province_Flemish Brabant', 'province_Hainaut', 'province_Limburg', 'province_Liège', 'province_Luxembourg', 'province_Namur', 'province_Walloon Brabant', 'province_West Flanders', "locality_'S-GRAVENWEZEL", "locality_'s-Gravenwezel", 'locality_AALBEKE', 'locality_AALST', 'locality_AARSCHOT', 'locality_AARTSELAAR', 'locality_ACHTERBROEK', 'locality_ACHÊNE', 'locality_ADINKERKE', 'locality_AISEAU', 'locality_ALKEN', 'locality_ALLEUR', 'locality_ALSEMBERG', 'locality_AMAY', 'locality_AMOUGIES', 'locality_AMPSIN', 'locality_ANDENNE', 'locality_ANDERLECHT', 'locality_ANDERLUES', 'locality_ANGLEUR', 'locality_ANNEVOIE-ROUILLON', 'locality_ANS', 'locality_ANSEREMME', 'locality_ANTOING', 'locality_ANTWERPEN', 'locality_ANZEGEM', 'locality_APPELS', 'locality_ARCHENNES', 'locality_ARENDONK', 'locality_ARGENTEAU', 'locality_ARLON', 'locality_ARQUENNES', 'locality_ASPER', 'locality_ASSE', 'locality_ASSENEDE', 'locality_ASSESSE', 'locality_ASTENE', 'locality_ATH', 'locality_ATHUS', 'locality_ATTERT', 'locality_AUBANGE', 'locality_AUDERGHEM', 'locality_AULNOIS', 'locality_AUVELAIS', 'locality_AVELGEM', 'locality_AVERBODE', 'locality_AVERNAS-LE-BAUDUIN', 'locality_AVIN', 'locality_AWANS', 'locality_AWIRS', 'locality_AYWAILLE', 'locality_Aalbeke', 'locality_Aalst', 'locality_Aalst (9300)', 'locality_Aalst - Baardegem', 'locality_Aalst Baardegem', 'locality_Aalst Erembodegem', 'locality_Aalst Gijzegem', 'locality_Aalst Moorsel', 'locality_Aalst Nieuwerkerken', 'locality_Aalter', 'locality_Aarlen', 'locality_Aarschot', 'locality_Aarschot Langdorp', 'lo ...
# training data did not have the following fields: locality_Virton Saint-Mard, locality_NEERPELT, locality_Willebroek Heindonk, locality_Charleroi Mont-sur-Marchienne, locality_Loverval, locality_Lambusart, locality_Oudergem, locality_CORROY-LE-GRAND, locality_Villers-le-Bouillet, locality_Jandrain-jandrenouille, locality_ELVERDINGE, locality_ANDERLECHT, locality_PELLENBERG, locality_Saint-Georgessur-Meuse, locality_VILLERS-LA-LOUE, locality_Heist-aan-Zee, locality_Hasselt Kermt, locality_Antwerpen Kiel, locality_Lochristi, locality_VELTEM-BEISEM, locality_DWORP, locality_Bonheiden Rijmenam, locality_Berchem, locality_Ichtegem, locality_WALEM, locality_WICHELEN, locality_FONTAINE-L'EVEQUE, locality_La Louvière Saint-Vaast, locality_Strombeek-Bever, locality_Waregem Beveren-Leie, locality_PONT-DE-LOUP, epcScore_A++, locality_Thimister, locality_LOKEREN, locality_Pont-de-loup, locality_Lauw, locality_HEURE,
['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'type_HOUSE', 'subtype_APARTMENT', 'subtype_APARTMENT_BLOCK', 'subtype_DUPLEX', 'subtype_GROUND_FLOOR', 'subtype_HOUSE', 'subtype_MIXED_USE_BUILDING', 'subtype_PENTHOUSE', 'subtype_TOWN_HOUSE', 'subtype_VILLA', 'province_Antwerp', 'province_Brussels', 'province_East Flanders', 'province_Flemish Brabant', 'province_Hainaut', 'province_Limburg', 'province_Liège', 'province_Luxembourg', 'province_Namur', 'province_Walloon Brabant', 'province_West Flanders', 'locality_Anderlecht', 'locality_Antwerpen', 'locality_Bruxelles', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke-Heist', 'locality_Liège', 'locality_Uccle', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_JUST_RENOVATED', 'buildingCondition_TO_BE_DONE_UP', 'buildingCondition_TO_RENOVATE', 'buildingCondition_nan', 'floodZoneType_NON_FLOOD_ZONE', 'floodZoneType_POSSIBLE_FLOOD_ZONE', 'floodZoneType_RECOGNIZED_FLOOD_ZONE', 'floodZoneType_nan', 'heatingType_ELECTRIC', 'heatingType_FUELOIL', 'heatingType_GAS', 'heatingType_PELLET', 'heatingType_nan', 'kitchenType_HYPER_EQUIPPED', 'kitchenType_INSTALLED', 'kitchenType_NOT_INSTALLED', 'kitchenType_SEMI_EQUIPPED', 'kitchenType_USA_HYPER_EQUIPPED', 'kitchenType_USA_INSTALLED', 'kitchenType_nan', 'epcScore_A', 'epcScore_A+', 'epcScore_B', 'epcScore_C', 'epcScore_D', 'epcScore_E', 'epcScore_F', 'epcScore_G', 'hasLivingRoom', 'hasTerrace'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'is_big_property', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'type_HOUSE', 'subtype_APARTMENT', 'subtype_APARTMENT_BLOCK', 'subtype_BUNGALOW', 'subtype_CHALET', 'subtype_COUNTRY_COTTAGE', 'subtype_DUPLEX', 'subtype_EXCEPTIONAL_PROPERTY', 'subtype_FARMHOUSE', 'subtype_FLAT_STUDIO', 'subtype_GROUND_FLOOR', 'subtype_HOUSE', 'subtype_KOT', 'subtype_LOFT', 'subtype_MANOR_HOUSE', 'subtype_MANSION', 'subtype_MIXED_USE_BUILDING', 'subtype_OTHER_PROPERTY', 'subtype_PENTHOUSE', 'subtype_SERVICE_FLAT', 'subtype_TOWN_HOUSE', 'subtype_TRIPLEX', 'subtype_VILLA', 'province_Antwerp', 'province_Brussels', 'province_East Flanders', 'province_Flemish Brabant', 'province_Hainaut', 'province_Limburg', 'province_Liège', 'province_Luxembourg', 'province_Namur', 'province_Walloon Brabant', 'province_West Flanders', "locality_'S-GRAVENWEZEL", "locality_'s-Gravenwezel", 'locality_AALBEKE', 'locality_AALST', 'locality_AARSCHOT', 'locality_AARTSELAAR', 'locality_ACHTERBROEK', 'locality_ACHÊNE', 'locality_ADINKERKE', 'locality_AISEAU', 'locality_ALKEN', 'locality_ALLEUR', 'locality_ALSEMBERG', 'locality_AMAY', 'locality_AMOUGIES', 'locality_AMPSIN', 'locality_ANDENNE', 'locality_ANDERLECHT', 'locality_ANDERLUES', 'locality_ANGLEUR', 'locality_ANNEVOIE-ROUILLON', 'locality_ANS', 'locality_ANSEREMME', 'locality_ANTOING', 'locality_ANTWERPEN', 'locality_ANZEGEM', 'locality_APPELS', 'locality_ARCHENNES', 'locality_ARENDONK', 'locality_ARGENTEAU', 'locality_ARLON', 'locality_ARQUENNES', 'locality_ASPER', 'locality_ASSE', 'locality_ASSENEDE', 'locality_ASSESSE', 'locality_ASTENE', 'locality_ATH', 'locality_ATHUS', 'locality_ATTERT', 'locality_AUBANGE', 'locality_AUDERGHEM', 'locality_AULNOIS', 'locality_AUVELAIS', 'locality_AVELGEM', 'locality_AVERBODE', 'locality_AVERNAS-LE-BAUDUIN', 'locality_AVIN', 'locality_AWANS', 'locality_AWIRS', 'locality_A
locality_Vance, locality_TOHOGNE, locality_Hakendover, locality_VILLERS-SAINTE-GERTRUDE, locality_Mont (Yvoir), locality_Antoing, locality_Nieuwenhove, locality_Merksplas, locality_Celles Velaines, locality_Hannut Poucet, locality_Remicourt, locality_LAEKEN (BRU.), locality_TARCIENNE, locality_HABAY, locality_BOOISCHOT, locality_Godinne, locality_Orp-Jauche, locality_Grâce-hollogne, locality_Ronsele, locality_Jupille-sur-Meuse, locality_Blankenberghe, locality_AUVELAIS, locality_Lierde, locality_PETIT-ENGHIEN, locality_Melle, locality_Overijse, locality_SINAAI-WAAS, locality_Bambrugge, locality_SCHAERBEEK, locality_Cortenbergh, locality_Oplinter, locality_Faimes, locality_CRISNÉE, locality_HERVE, locality_BAASRODE, locality_Verlaine, locality_Fléron Romsée, locality_Tertre, locality_Thy-le-château, locality_Wechelderzande, locality_Herzele, locality_HEIKRUIS, locality_Manderfeld, locality_Temse, locality_Londerzeel-Sint-Jozef, locality_Vlijtingen, locality_LETTELINGEN, locality_NOTHOMB, locality_Genappe, locality_Forest, locality_KRUIBEKE, locality_Geetbets, locality_Ohain, locality_Mortsel, locality_CHIMAY, locality_La Roche-en-Ardenne, Halleux, locality_Barchon, locality_OPHASSELT, subtype_OTHER_PROPERTY, locality_BEHO, locality_Jemeppe-Sur-Meuse, locality_MELSBROEK, locality_LOMBISE, locality_WASMES, locality_WANFERCÉE-BAULET, locality_TOURNAI, locality_H ...
# Failed prediction for model 'xgboost_optuna_all_20250629_1030_TEST': feature_names mismatch: ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'type_HOUSE', 'subtype_APARTMENT', 'subtype_APARTMENT_BLOCK', 'subtype_DUPLEX', 'subtype_GROUND_FLOOR', 'subtype_HOUSE', 'subtype_MIXED_USE_BUILDING', 'subtype_PENTHOUSE', 'subtype_TOWN_HOUSE', 'subtype_VILLA', 'province_Antwerp', 'province_Brussels', 'province_East Flanders', 'province_Flemish Brabant', 'province_Hainaut', 'province_Limburg', 'province_Liège', 'province_Luxembourg', 'province_Namur', 'province_Walloon Brabant', 'province_West Flanders', 'locality_Anderlecht', 'locality_Antwerpen', 'locality_Bruxelles', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke-Heist', 'locality_Liège', 'locality_Uccle', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_JUST_RENOVATED', 'buildingCondition_TO_BE_DONE_UP', 'buildingCondition_TO_RENOVATE', 'buildingCondition_nan', 'floodZoneType_NON_FLOOD_ZONE', 'floodZoneType_POSSIBLE_FLOOD_ZONE', 'floodZoneType_RECOGNIZED_FLOOD_ZONE', 'floodZoneType_nan', 'heatingType_ELECTRIC', 'heatingType_FUELOIL', 'heatingType_GAS', 'heatingType_PELLET', 'heatingType_nan', 'kitchenType_HYPER_EQUIPPED', 'kitchenType_INSTALLED', 'kitchenType_NOT_INSTALLED', 'kitchenType_SEMI_EQUIPPED', 'kitchenType_USA_HYPER_EQUIPPED', 'kitchenType_USA_INSTALLED', 'kitchenType_nan', 'epcScore_A', 'epcScore_A+', 'epcScore_B', 'epcScore_C', 'epcScore_D', 'epcScore_E', 'epcScore_F', 'epcScore_G', 'hasLivingRoom', 'hasTerrace'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'is_big_property', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'type_HOUSE', 'subtype_APARTMENT', 'subtype_APARTMENT_BLOCK', 'subtype_BUNGALOW', 'subtype_CHALET', 'subtype_COUNTRY_COTTAGE', 'subtype_DUPLEX', 'subtype_EXCEPTIONAL_PROPERTY', 'subtype_FARMHOUSE', 'subtype_FLAT_STUDIO', 'subtype_GROUND_FLOOR', 'subtype_HOUSE', 'subtype_KOT', 'subtype_LOFT', 'subtype_MANOR_HOUSE', 'subtype_MANSION', 'subtype_MIXED_USE_BUILDING', 'subtype_OTHER_PROPERTY', 'subtype_PENTHOUSE', 'subtype_SERVICE_FLAT', 'subtype_TOWN_HOUSE', 'subtype_TRIPLEX', 'subtype_VILLA', 'province_Antwerp', 'province_Brussels', 'province_East Flanders', 'province_Flemish Brabant', 'province_Hainaut', 'province_Limburg', 'province_Liège', 'province_Luxembourg', 'province_Namur', 'province_Walloon Brabant', 'province_West Flanders', "locality_'S-GRAVENWEZEL", "locality_'s-Gravenwezel", 'locality_AALBEKE', 'locality_AALST', 'locality_AARSCHOT', 'locality_AARTSELAAR', 'locality_ACHTERBROEK', 'locality_ACHÊNE', 'locality_ADINKERKE', 'locality_AISEAU', 'locality_ALKEN', 'locality_ALLEUR', 'locality_ALSEMBERG', 'locality_AMAY', 'locality_AMOUGIES', 'locality_AMPSIN', 'locality_ANDENNE', 'locality_ANDERLECHT', 'locality_ANDERLUES', 'locality_ANGLEUR', 'locality_ANNEVOIE-ROUILLON', 'locality_ANS', 'locality_ANSEREMME', 'locality_ANTOING', 'locality_ANTWERPEN', 'locality_ANZEGEM', 'locality_APPELS', 'locality_ARCHENNES', 'locality_ARENDONK', 'locality_ARGENTEAU', 'locality_ARLON', 'locality_ARQUENNES', 'locality_ASPER', 'locality_ASSE', 'locality_ASSENEDE', 'locality_ASSESSE', 'locality_ASTENE', 'locality_ATH', 'locality_ATHUS', 'locality_ATTERT', 'locality_AUBANGE', 'locality_AUDERGHEM', 'locality_AULNOIS', 'locality_AUVELAIS', 'locality_AVELGEM', 'locality_AVERBODE', 'locality_AVERNAS-LE-BAUDUIN', 'locality_AVIN', 'locality_AWANS', 'locality_AWIRS', 'locality_AYWAILLE', 'locality_Aalbeke', 'locality_Aalst', 'locality_Aalst (9300)', 'locality_Aalst - Baardegem', 'locality_Aalst Baardegem', 'locality_Aalst Erembodegem', 'locality_Aalst Gijzegem', 'locality_Aalst Moorsel', 'locality_Aalst Nieuwerkerken', 'locality_Aalter', 'locality_Aarlen', 'locality_Aarschot', 'locality_Aarschot Langdorp', 'lo ...
# training data did not have the following fields: locality_Virton Saint-Mard, locality_NEERPELT, locality_Willebroek Heindonk, locality_Charleroi Mont-sur-Marchienne, locality_Loverval, locality_Lambusart, locality_Oudergem, locality_CORROY-LE-GRAND, locality_Villers-le-Bouillet, locality_Jandrain-jandrenouille, locality_ELVERDINGE, locality_ANDERLECHT, locality_PELLENBERG, locality_Saint-Georgessur-Meuse, locality_VILLERS-LA-LOUE, locality_Heist-aan-Zee, locality_Hasselt Kermt, locality_Antwerpen Kiel, locality_Lochristi, locality_VELTEM-BEISEM, locality_DWORP, locality_Bonheiden Rijmenam, locality_Berchem, locality_Ichtegem, locality_WALEM, locality_WICHELEN, locality_FONTAINE-L'EVEQUE, locality_La Louvière Saint-Vaast, locality_Strombeek-Bever, locality_Waregem Beveren-Leie, locality_PONT-DE-LOUP, epcScore_A++, locality_Thimister, locality_LOKEREN, locality_Pont-de-loup, locality_Lauw, locality_HEURE, locality_Modave Outrelouxhe, locality_VITRIVAL, locality_Wervik, locality_ANDENNE, locality_Ninove, locality_Ooigem, locality_HOEGAARDEN, locality_Court-saint-Étienne, locality_LAMBUSART, locality_Vaux-sous-Chèvremont, locality_Marcinelle, locality_Bornem Hingene, locality_ZELLIK, locality_Diksmuide, locality_Evregnies, locality_Kortrijk-Dutsel, locality_BAZEL, locality_Leeuw-Saint-Pierre, locality_Zonhoven, locality_Molenbeersel, locality_Saint-nicolas, locality_Tongeren, locality_BACHTE-MARIA-LEERNE, locality_Feneur, locality_Hoogstraten, locality_PUURS-SINT-AMANDS, locality_Awans Othée, locality_WAREGEM, locality_Jodoigne, locality_ATHUS, locality_Louveigné, locality_Hulste, locality_Lommel, locality_COURCELLES, locality_Poppel, locality_GULLEGEM, locality_LATHUY, locality_SINT-PIETERS-LEEUW, locality_Willebroek Tisselt, locality_FIZE-FONTAINE, locality_Fayembois, locality_Francorchamps, locality_Chaudfontaine Beaufays, locality_QUIÉVRAIN, locality_Oppuurs, locality_Grimbergen Strombeek-Bever, locality_Sint-Denijs-Westrem, locality_Pâturages, locality_Gent Gentbrugge, locality_Ranst, locality_Wielsbeke, locality_LE ROEULX, locality_ARENDONK, locality_Zwevegem, locality_Mettet Ermetonsur-Biert, locality_Schendelbeke, locality_Gedinne Louette-Saint-Denis, locality_Messancy Wolkrange, locality_Leuven Wilsele, locality_Herseaux, locality_ALLEUR, locality_Sint-Lambrechts-Woluwe, locality_Herve Battice, locality_Heist-op-den-Berg Wiekevorst, locality_Hoogstraten Wortel, locality_HERENT, locality_Onhaye Sommière, locality_TIENEN, locality_Zwijnaarde, locality_Perwez Malèves-Ste-Marie-Wastines, locality_WAYAUX, locality_BRAKEL, locality_Veurne, locality_Florenville Chassepierre, locality_Vance, locality_TOHOGNE, locality_Hakendover, locality_VILLERS-SAINTE-GERTRUDE, locality_Mont (Yvoir), locality_Antoing, locality_Nieuwenhove, locality_Merksplas, locality_Celles Velaines, locality_Hannut Poucet, locality_Remicourt, locality_LAEKEN (BRU.), locality_TARCIENNE, locality_HABAY, locality_BOOISCHOT, locality_Godinne, locality_Orp-Jauche, locality_Grâce-hollogne, locality_Ronsele, locality_Jupille-sur-Meuse, locality_Blankenberghe, locality_AUVELAIS, locality_Lierde, locality_PETIT-ENGHIEN, locality_Melle, locality_Overijse, locality_SINAAI-WAAS, locality_Bambrugge, locality_SCHAERBEEK, locality_Cortenbergh, locality_Oplinter, locality_Faimes, locality_CRISNÉE, locality_HERVE, locality_BAASRODE, locality_Verlaine, locality_Fléron Romsée, locality_Tertre, locality_Thy-le-château, locality_Wechelderzande, locality_Herzele, locality_HEIKRUIS, locality_Manderfeld, locality_Temse, locality_Londerzeel-Sint-Jozef, locality_Vlijtingen, locality_LETTELINGEN, locality_NOTHOMB, locality_Genappe, locality_Forest, locality_KRUIBEKE, locality_Geetbets, locality_Ohain, locality_Mortsel, locality_CHIMAY, locality_La Roche-en-Ardenne, Halleux, locality_Barchon, locality_OPHASSELT, subtype_OTHER_PROPERTY, locality_BEHO, locality_Jemeppe-Sur-Meuse, locality_MELSBROEK, locality_LOMBISE, locality_WASMES, locality_WANFERCÉE-BAULET, locality_TOURNAI, locality_H ...
# Failed prediction for model 'xgboost_optuna_all_20250629_1052_TEST': feature_names mismatch: ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'type_HOUSE', 'subtype_APARTMENT', 'subtype_APARTMENT_BLOCK', 'subtype_DUPLEX', 'subtype_GROUND_FLOOR', 'subtype_HOUSE', 'subtype_MIXED_USE_BUILDING', 'subtype_PENTHOUSE', 'subtype_TOWN_HOUSE', 'subtype_VILLA', 'province_Antwerp', 'province_Brussels', 'province_East Flanders', 'province_Flemish Brabant', 'province_Hainaut', 'province_Limburg', 'province_Liège', 'province_Luxembourg', 'province_Namur', 'province_Walloon Brabant', 'province_West Flanders', 'locality_Anderlecht', 'locality_Antwerpen', 'locality_Bruxelles', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke-Heist', 'locality_Liège', 'locality_Uccle', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_JUST_RENOVATED', 'buildingCondition_TO_BE_DONE_UP', 'buildingCondition_TO_RENOVATE', 'buildingCondition_nan', 'floodZoneType_NON_FLOOD_ZONE', 'floodZoneType_POSSIBLE_FLOOD_ZONE', 'floodZoneType_RECOGNIZED_FLOOD_ZONE', 'floodZoneType_nan', 'heatingType_ELECTRIC', 'heatingType_FUELOIL', 'heatingType_GAS', 'heatingType_PELLET', 'heatingType_nan', 'kitchenType_HYPER_EQUIPPED', 'kitchenType_INSTALLED', 'kitchenType_NOT_INSTALLED', 'kitchenType_SEMI_EQUIPPED', 'kitchenType_USA_HYPER_EQUIPPED', 'kitchenType_USA_INSTALLED', 'kitchenType_nan', 'epcScore_A', 'epcScore_A+', 'epcScore_B', 'epcScore_C', 'epcScore_D', 'epcScore_E', 'epcScore_F', 'epcScore_G', 'hasLivingRoom', 'hasTerrace'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'is_big_property', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'type_HOUSE', 'subtype_APARTMENT', 'subtype_APARTMENT_BLOCK', 'subtype_BUNGALOW', 'subtype_CHALET', 'subtype_COUNTRY_COTTAGE', 'subtype_DUPLEX', 'subtype_EXCEPTIONAL_PROPERTY', 'subtype_FARMHOUSE', 'subtype_FLAT_STUDIO', 'subtype_GROUND_FLOOR', 'subtype_HOUSE', 'subtype_KOT', 'subtype_LOFT', 'subtype_MANOR_HOUSE', 'subtype_MANSION', 'subtype_MIXED_USE_BUILDING', 'subtype_OTHER_PROPERTY', 'subtype_PENTHOUSE', 'subtype_SERVICE_FLAT', 'subtype_TOWN_HOUSE', 'subtype_TRIPLEX', 'subtype_VILLA', 'province_Antwerp', 'province_Brussels', 'province_East Flanders', 'province_Flemish Brabant', 'province_Hainaut', 'province_Limburg', 'province_Liège', 'province_Luxembourg', 'province_Namur', 'province_Walloon Brabant', 'province_West Flanders', "locality_'S-GRAVENWEZEL", "locality_'s-Gravenwezel", 'locality_AALBEKE', 'locality_AALST', 'locality_AARSCHOT', 'locality_AARTSELAAR', 'locality_ACHTERBROEK', 'locality_ACHÊNE', 'locality_ADINKERKE', 'locality_AISEAU', 'locality_ALKEN', 'locality_ALLEUR', 'locality_ALSEMBERG', 'locality_AMAY', 'locality_AMOUGIES', 'locality_AMPSIN', 'locality_ANDENNE', 'locality_ANDERLECHT', 'locality_ANDERLUES', 'locality_ANGLEUR', 'locality_ANNEVOIE-ROUILLON', 'locality_ANS', 'locality_ANSEREMME', 'locality_ANTOING', 'locality_ANTWERPEN', 'locality_ANZEGEM', 'locality_APPELS', 'locality_ARCHENNES', 'locality_ARENDONK', 'locality_ARGENTEAU', 'locality_ARLON', 'locality_ARQUENNES', 'locality_ASPER', 'locality_ASSE', 'locality_ASSENEDE', 'locality_ASSESSE', 'locality_ASTENE', 'locality_ATH', 'locality_ATHUS', 'locality_ATTERT', 'locality_AUBANGE', 'locality_AUDERGHEM', 'locality_AULNOIS', 'locality_AUVELAIS', 'locality_AVELGEM', 'locality_AVERBODE', 'locality_AVERNAS-LE-BAUDUIN', 'locality_AVIN', 'locality_AWANS', 'locality_AWIRS', 'locality_AYWAILLE', 'locality_Aalbeke', 'locality_Aalst', 'locality_Aalst (9300)', 'locality_Aalst - Baardegem', 'locality_Aalst Baardegem', 'locality_Aalst Erembodegem', 'locality_Aalst Gijzegem', 'locality_Aalst Moorsel', 'locality_Aalst Nieuwerkerken', 'locality_Aalter', 'locality_Aarlen', 'locality_Aarschot', 'locality_Aarschot Langdorp', 'lo ...
-SAINTE-GERTRUDE, locality_Mont (Yvoir), locality_Antoing, locality_Nieuwenhove, locality_Merksplas, locality_Celles Velaines, locality_Hannut Poucet, locality_Remicourt, locality_LAEKEN (BRU.), locality_TARCIENNE, locality_HABAY, locality_BOOISCHOT, locality_Godinne, locality_Orp-Jauche, locality_Grâce-hollogne, locality_Ronsele, locality_Jupille-sur-Meuse, locality_Blankenberghe, locality_AUVELAIS, locality_Lierde, locality_PETIT-ENGHIEN, locality_Melle, locality_Overijse, locality_SINAAI-WAAS, locality_Bambrugge, locality_SCHAERBEEK, locality_Cortenbergh, locality_Oplinter, locality_Faimes, locality_CRISNÉE, locality_HERVE, locality_BAASRODE, locality_Verlaine, locality_Fléron Romsée, locality_Tertre, locality_Thy-le-château, locality_Wechelderzande, locality_Herzele, locality_HEIKRUIS, locality_Manderfeld, locality_Temse, locality_Londerzeel-Sint-Jozef, locality_Vlijtingen, locality_LETTELINGEN, locality_NOTHOMB, locality_Genappe, locality_Forest, locality_KRUIBEKE, locality_Geetbets, locality_Ohain, locality_Mortsel, locality_CHIMAY, locality_La Roche-en-Ardenne, Halleux, locality_Barchon, locality_OPHASSELT, subtype_OTHER_PROPERTY, locality_BEHO, locality_Jemeppe-Sur-Meuse, locality_MELSBROEK, locality_LOMBISE, locality_WASMES, locality_WANFERCÉE-BAULET, locality_TOURNAI, locality_H ...
# ...
# expected kitchenType_INSTALLED, heatingType_nan, epcScore_F in input data
# training data did not have the following fields: locality_Knokke, locality_Knokke-Zoute, type_APARTMENT
# Failed prediction for model 'xgboost_optuna_top30_20250629_1314_TEST': feature_names mismatch: ['habitableSurface', 'bathroomCount', 'postCode', 'toiletCount', 'buildingConstructionYear', 'locality_Knokke-Heist', 'building_age', 'surface_per_room', 'facedeCount', 'kitchenType_HYPER_EQUIPPED', 'buildingCondition_AS_NEW', 'province_West Flanders', 'subtype_VILLA', 'subtype_HOUSE', 'province_Hainaut', 'room_count', 'bedroomCount', 'buildingCondition_TO_RENOVATE', 'epcScore_B', 'hasTerrace', 'subtype_PENTHOUSE', 'epcScore_C', 'buildingCondition_GOOD', 'heatingType_nan', 'hasLivingRoom', 'locality_Ixelles', 'kitchenType_INSTALLED', 'epcScore_A', 'epcScore_F', 'locality_Gent'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'subtype_HOUSE', 'subtype_PENTHOUSE', 'subtype_VILLA', 'province_Hainaut', 'province_West Flanders', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke', 'locality_Knokke-Heist', 'locality_Knokke-Zoute', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_TO_RENOVATE', 'kitchenType_HYPER_EQUIPPED', 'epcScore_A', 'epcScore_B', 'epcScore_C', 'hasLivingRoom', 'hasTerrace']
# expected kitchenType_INSTALLED, heatingType_nan, epcScore_F in input data
# training data did not have the following fields: locality_Knokke, locality_Knokke-Zoute, type_APARTMENT
# Failed prediction for model 'xgboost_optuna_top30_20250629_1317_TEST': feature_names mismatch: ['habitableSurface', 'bathroomCount', 'postCode', 'toiletCount', 'buildingConstructionYear', 'locality_Knokke-Heist', 'building_age', 'surface_per_room', 'facedeCount', 'kitchenType_HYPER_EQUIPPED', 'buildingCondition_AS_NEW', 'province_West Flanders', 'subtype_VILLA', 'subtype_HOUSE', 'province_Hainaut', 'room_count', 'bedroomCount', 'buildingCondition_TO_RENOVATE', 'epcScore_B', 'hasTerrace', 'subtype_PENTHOUSE', 'epcScore_C', 'buildingCondition_GOOD', 'heatingType_nan', 'hasLivingRoom', 'locality_Ixelles', 'kitchenType_INSTALLED', 'epcScore_A', 'epcScore_F', 'locality_Gent'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'subtype_HOUSE', 'subtype_PENTHOUSE', 'subtype_VILLA', 'province_Hainaut', 'province_West Flanders', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke', 'locality_Knokke-Heist', 'locality_Knokke-Zoute', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_TO_RENOVATE', 'kitchenType_HYPER_EQUIPPED', 'epcScore_A', 'epcScore_B', 'epcScore_C', 'hasLivingRoom', 'hasTerrace']
# expected kitchenType_INSTALLED, heatingType_nan, epcScore_F in input data
# training data did not have the following fields: locality_Knokke, locality_Knokke-Zoute, type_APARTMENT
# Failed prediction for model 'xgboost_optuna_top30_20250629_1326_TEST': feature_names mismatch: ['habitableSurface', 'bathroomCount', 'postCode', 'toiletCount', 'buildingConstructionYear', 'locality_Knokke-Heist', 'building_age', 'surface_per_room', 'facedeCount', 'kitchenType_HYPER_EQUIPPED', 'buildingCondition_AS_NEW', 'province_West Flanders', 'subtype_VILLA', 'subtype_HOUSE', 'province_Hainaut', 'room_count', 'bedroomCount', 'buildingCondition_TO_RENOVATE', 'epcScore_B', 'hasTerrace', 'subtype_PENTHOUSE', 'epcScore_C', 'buildingCondition_GOOD', 'heatingType_nan', 'hasLivingRoom', 'locality_Ixelles', 'kitchenType_INSTALLED', 'epcScore_A', 'epcScore_F', 'locality_Gent'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'subtype_HOUSE', 'subtype_PENTHOUSE', 'subtype_VILLA', 'province_Hainaut', 'province_West Flanders', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke', 'locality_Knokke-Heist', 'locality_Knokke-Zoute', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_TO_RENOVATE', 'kitchenType_HYPER_EQUIPPED', 'epcScore_A', 'epcScore_B', 'epcScore_C', 'hasLivingRoom', 'hasTerrace']
# expected kitchenType_INSTALLED, heatingType_nan, epcScore_F in input data
# training data did not have the following fields: locality_Knokke, locality_Knokke-Zoute, type_APARTMENT
# Failed prediction for model 'xgboost_optuna_top30_20250629_1339_TEST': feature_names mismatch: ['habitableSurface', 'bathroomCount', 'postCode', 'toiletCount', 'buildingConstructionYear', 'locality_Knokke-Heist', 'building_age', 'surface_per_room', 'facedeCount', 'kitchenType_HYPER_EQUIPPED', 'buildingCondition_AS_NEW', 'province_West Flanders', 'subtype_VILLA', 'subtype_HOUSE', 'province_Hainaut', 'room_count', 'bedroomCount', 'buildingCondition_TO_RENOVATE', 'epcScore_B', 'hasTerrace', 'subtype_PENTHOUSE', 'epcScore_C', 'buildingCondition_GOOD', 'heatingType_nan', 'hasLivingRoom', 'locality_Ixelles', 'kitchenType_INSTALLED', 'epcScore_A', 'epcScore_F', 'locality_Gent'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'subtype_HOUSE', 'subtype_PENTHOUSE', 'subtype_VILLA', 'province_Hainaut', 'province_West Flanders', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke', 'locality_Knokke-Heist', 'locality_Knokke-Zoute', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_TO_RENOVATE', 'kitchenType_HYPER_EQUIPPED', 'epcScore_A', 'epcScore_B', 'epcScore_C', 'hasLivingRoom', 'hasTerrace']
# expected kitchenType_INSTALLED, heatingType_nan, epcScore_F in input data
# training data did not have the following fields: locality_Knokke, locality_Knokke-Zoute, type_APARTMENT
# Failed prediction for model 'xgboost_optuna_top30_20250629_1405_TEST': feature_names mismatch: ['habitableSurface', 'bathroomCount', 'postCode', 'toiletCount', 'buildingConstructionYear', 'locality_Knokke-Heist', 'building_age', 'surface_per_room', 'facedeCount', 'kitchenType_HYPER_EQUIPPED', 'buildingCondition_AS_NEW', 'province_West Flanders', 'subtype_VILLA', 'subtype_HOUSE', 'province_Hainaut', 'room_count', 'bedroomCount', 'buildingCondition_TO_RENOVATE', 'epcScore_B', 'hasTerrace', 'subtype_PENTHOUSE', 'epcScore_C', 'buildingCondition_GOOD', 'heatingType_nan', 'hasLivingRoom', 'locality_Ixelles', 'kitchenType_INSTALLED', 'epcScore_A', 'epcScore_F', 'locality_Gent'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'subtype_HOUSE', 'subtype_PENTHOUSE', 'subtype_VILLA', 'province_Hainaut', 'province_West Flanders', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke', 'locality_Knokke-Heist', 'locality_Knokke-Zoute', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_TO_RENOVATE', 'kitchenType_HYPER_EQUIPPED', 'epcScore_A', 'epcScore_B', 'epcScore_C', 'hasLivingRoom', 'hasTerrace']
# expected kitchenType_INSTALLED, heatingType_nan, epcScore_F in input data
# training data did not have the following fields: locality_Knokke, locality_Knokke-Zoute, type_APARTMENT
# Failed prediction for model 'xgboost_optuna_top30_20250629_1422_TEST': feature_names mismatch: ['habitableSurface', 'bathroomCount', 'postCode', 'toiletCount', 'buildingConstructionYear', 'locality_Knokke-Heist', 'building_age', 'surface_per_room', 'facedeCount', 'kitchenType_HYPER_EQUIPPED', 'buildingCondition_AS_NEW', 'province_West Flanders', 'subtype_VILLA', 'subtype_HOUSE', 'province_Hainaut', 'room_count', 'bedroomCount', 'buildingCondition_TO_RENOVATE', 'epcScore_B', 'hasTerrace', 'subtype_PENTHOUSE', 'epcScore_C', 'buildingCondition_GOOD', 'heatingType_nan', 'hasLivingRoom', 'locality_Ixelles', 'kitchenType_INSTALLED', 'epcScore_A', 'epcScore_F', 'locality_Gent'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'subtype_HOUSE', 'subtype_PENTHOUSE', 'subtype_VILLA', 'province_Hainaut', 'province_West Flanders', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke', 'locality_Knokke-Heist', 'locality_Knokke-Zoute', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_TO_RENOVATE', 'kitchenType_HYPER_EQUIPPED', 'epcScore_A', 'epcScore_B', 'epcScore_C', 'hasLivingRoom', 'hasTerrace']
# expected kitchenType_INSTALLED, heatingType_nan, epcScore_F in input data
# training data did not have the following fields: locality_Knokke, locality_Knokke-Zoute, type_APARTMENT
# Failed prediction for model 'xgboost_optuna_top30_20250629_1440_TEST': feature_names mismatch: ['habitableSurface', 'bathroomCount', 'postCode', 'toiletCount', 'buildingConstructionYear', 'locality_Knokke-Heist', 'building_age', 'surface_per_room', 'facedeCount', 'kitchenType_HYPER_EQUIPPED', 'buildingCondition_AS_NEW', 'province_West Flanders', 'subtype_VILLA', 'subtype_HOUSE', 'province_Hainaut', 'room_count', 'bedroomCount', 'buildingCondition_TO_RENOVATE', 'epcScore_B', 'hasTerrace', 'subtype_PENTHOUSE', 'epcScore_C', 'buildingCondition_GOOD', 'heatingType_nan', 'hasLivingRoom', 'locality_Ixelles', 'kitchenType_INSTALLED', 'epcScore_A', 'epcScore_F', 'locality_Gent'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'subtype_HOUSE', 'subtype_PENTHOUSE', 'subtype_VILLA', 'province_Hainaut', 'province_West Flanders', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke', 'locality_Knokke-Heist', 'locality_Knokke-Zoute', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_TO_RENOVATE', 'kitchenType_HYPER_EQUIPPED', 'epcScore_A', 'epcScore_B', 'epcScore_C', 'hasLivingRoom', 'hasTerrace']
# expected kitchenType_INSTALLED, heatingType_nan, epcScore_F in input data
# training data did not have the following fields: locality_Knokke, locality_Knokke-Zoute, type_APARTMENT
# Failed prediction for model 'xgboost_optuna_top30_20250629_1517_TEST': feature_names mismatch: ['habitableSurface', 'bathroomCount', 'postCode', 'toiletCount', 'buildingConstructionYear', 'locality_Knokke-Heist', 'building_age', 'surface_per_room', 'facedeCount', 'kitchenType_HYPER_EQUIPPED', 'buildingCondition_AS_NEW', 'province_West Flanders', 'subtype_VILLA', 'subtype_HOUSE', 'province_Hainaut', 'room_count', 'bedroomCount', 'buildingCondition_TO_RENOVATE', 'epcScore_B', 'hasTerrace', 'subtype_PENTHOUSE', 'epcScore_C', 'buildingCondition_GOOD', 'heatingType_nan', 'hasLivingRoom', 'locality_Ixelles', 'kitchenType_INSTALLED', 'epcScore_A', 'epcScore_F', 'locality_Gent'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'subtype_HOUSE', 'subtype_PENTHOUSE', 'subtype_VILLA', 'province_Hainaut', 'province_West Flanders', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke', 'locality_Knokke-Heist', 'locality_Knokke-Zoute', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_TO_RENOVATE', 'kitchenType_HYPER_EQUIPPED', 'epcScore_A', 'epcScore_B', 'epcScore_C', 'hasLivingRoom', 'hasTerrace']
# expected kitchenType_INSTALLED, heatingType_nan, epcScore_F in input data
# training data did not have the following fields: locality_Knokke, locality_Knokke-Zoute, type_APARTMENT
# Failed prediction for model 'xgboost_optuna_top30_20250629_1523_TEST': feature_names mismatch: ['habitableSurface', 'bathroomCount', 'postCode', 'toiletCount', 'buildingConstructionYear', 'locality_Knokke-Heist', 'building_age', 'surface_per_room', 'facedeCount', 'kitchenType_HYPER_EQUIPPED', 'buildingCondition_AS_NEW', 'province_West Flanders', 'subtype_VILLA', 'subtype_HOUSE', 'province_Hainaut', 'room_count', 'bedroomCount', 'buildingCondition_TO_RENOVATE', 'epcScore_B', 'hasTerrace', 'subtype_PENTHOUSE', 'epcScore_C', 'buildingCondition_GOOD', 'heatingType_nan', 'hasLivingRoom', 'locality_Ixelles', 'kitchenType_INSTALLED', 'epcScore_A', 'epcScore_F', 'locality_Gent'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'subtype_HOUSE', 'subtype_PENTHOUSE', 'subtype_VILLA', 'province_Hainaut', 'province_West Flanders', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke', 'locality_Knokke-Heist', 'locality_Knokke-Zoute', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_TO_RENOVATE', 'kitchenType_HYPER_EQUIPPED', 'epcScore_A', 'epcScore_B', 'epcScore_C', 'hasLivingRoom', 'hasTerrace']
# expected kitchenType_INSTALLED, heatingType_nan, epcScore_F in input data
# training data did not have the following fields: locality_Knokke, locality_Knokke-Zoute, type_APARTMENT
# Failed prediction for model 'xgboost_optuna_top30_20250629_1551_TEST': feature_names mismatch: ['habitableSurface', 'bathroomCount', 'postCode', 'toiletCount', 'buildingConstructionYear', 'locality_Knokke-Heist', 'building_age', 'surface_per_room', 'facedeCount', 'kitchenType_HYPER_EQUIPPED', 'buildingCondition_AS_NEW', 'province_West Flanders', 'subtype_VILLA', 'subtype_HOUSE', 'province_Hainaut', 'room_count', 'bedroomCount', 'buildingCondition_TO_RENOVATE', 'epcScore_B', 'hasTerrace', 'subtype_PENTHOUSE', 'epcScore_C', 'buildingCondition_GOOD', 'heatingType_nan', 'hasLivingRoom', 'locality_Ixelles', 'kitchenType_INSTALLED', 'epcScore_A', 'epcScore_F', 'locality_Gent'] ['bedroomCount', 'bathroomCount', 'postCode', 'habitableSurface', 'buildingConstructionYear', 'facedeCount', 'toiletCount', 'room_count', 'surface_per_room', 'building_age', 'type_APARTMENT', 'subtype_HOUSE', 'subtype_PENTHOUSE', 'subtype_VILLA', 'province_Hainaut', 'province_West Flanders', 'locality_Gent', 'locality_Ixelles', 'locality_Knokke', 'locality_Knokke-Heist', 'locality_Knokke-Zoute', 'buildingCondition_AS_NEW', 'buildingCondition_GOOD', 'buildingCondition_TO_RENOVATE', 'kitchenType_HYPER_EQUIPPED', 'epcScore_A', 'epcScore_B', 'epcScore_C', 'hasLivingRoom', 'hasTerrace']
# expected kitchenType_INSTALLED, heatingType_nan, epcScore_F in input data
# training data did not have the following fields: locality_Knokke, locality_Knokke-Zoute, type_APARTMENT
# Inference predictions saved to: e:\_SoftEng\_BeCode\real-estate-price-predictor\predictions\inference_predictions_20250629_1621.csv
